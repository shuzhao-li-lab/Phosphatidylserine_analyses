# %% [markdown]
# # Extract the MS2 scan and do signature neutral loss search
# - run multiple files
# - need to define a precursor target list & scan range (let's just try to do more inclusive one)

# %%
# !pip install pymzml
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt
import pymzml
import os
import pandas as pd
import sys

# %%
sys.path.append('../pyutils/')  # add the second parent directory
from searchMS2 import *

# %%
# spectrum.selected_precursors
# [{'mz': 417.320373535156, 'charge': 1, 'precursor id': '2'}]

# %%
dir_path = "../../../../MS_MS_raw_mzML/AX_RPneg_TDcells/mzML/"
files_and_dirs = os.listdir(dir_path)

# Get the full path for each file/directory in the list
infiles = [os.path.join(dir_path, file) for file in files_and_dirs]

# %%
exps = []
for infile in infiles:
    exps.append(pymzml.run.Reader(infile))
# Out:
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False

# %% [markdown]
# ## Basic information - using the first instance

# %%
exp = pymzml.run.Reader(infiles[0])
# Out:
# [Warning] Not index found and build_index_from_scratch is False

# %%
# How many spectra
exp.get_spectrum_count()
# Out:
# 4008

# %%
exp.ms_precisions # ms-level 1: ppm 5; ms-level 2: ppm 20?
# Out:
# {None: 0.0001, 0: 0.0001, 1: 5e-06, 2: 2e-05}

# %% [markdown]
# ##### summary
# - a probably 12 min run (720 secs) for 4008 scans
# - 0.17964 second/scan

# %% [markdown]
# ## Load target list

# %%
df_sel = pd.read_csv("./data/input/PS_sel_one_wayANOVA_hMinImp_TICnorm_groupFil0.3_RPneg_fullreport.csv")

# %%
df_sel.head(10)
# Out:
#   id_number      X.M.H. Species.Shorthand      Formula  Neutral_Mass  \
# 0    F10088  706.502297         PS O-31:0   C37H74NO9P    707.510122
# 1    F10378  798.528512           PS 37:3  C43H78NO10P    799.536337
# 2    F10486  734.533597         PS O-33:0   C39H78NO9P    735.541422
# 3    F11304  768.517947         PS O-36:4   C42H76NO9P    769.525772
# 4    F11498  810.528512           PS 38:4  C44H78NO10P    811.536337
# 5    F11849  772.549247         PS O-36:2   C42H80NO9P    773.557072
# 6    F12641  820.512862           PS 39:6  C45H76NO10P    821.520687
# 7    F12819  748.512862           PS 33:0  C39H76NO10P    749.520687
# 8    F12928  784.549247         PS O-37:3   C43H80NO9P    785.557072
# 9    F13113  832.512862           PS 40:7  C46H76NO10P    833.520687
#
#                                          Common.Name   gMean_Tn  \
# 0                    PS(O-16:0/15:0);PS(O-18:0/13:0)  22.549751
# 1  PS(15:1(9Z)/22:2(13Z,16Z));PS(17:0/20:3(8Z,11Z...  19.066357
# 2    PS(O-18:0/15:0);PS(O-20:0/13:0);PS(O-16:0/17:0)  21.706523
# 3  PS(O-18:0/18:4(6Z,9Z,12Z,15Z));PS(P-16:0/20:3(...  18.886893
# 4  PS(18:0/20:4(5Z,8Z,11Z,14Z));PS(18:1(9Z)/20:3(...  22.049175
# 5  PS(O-16:0/20:2(11Z,14Z));PS(O-18:0/18:2(9Z,12Z...  20.942226
# 6  PS(17:2(9Z,12Z)/22:4(7Z,10Z,13Z,16Z));PS(19:1(...  17.989310
# 7  PS(12:0/21:0);PS(14:0/19:0);PS(17:0/16:0);PS(1...  21.203391
# 8                            PS(P-20:0/17:2(9Z,12Z))  20.746608
# 9  PS(18:1(9Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z));PS(18...  20.891264
#
#    gMean_CD8stem  gMean_CD8trans  gMean_CD8TD  ...  CD8TD_750K_2  \
# 0      22.242303       22.232876    21.812267  ...     21.861243
# 1      19.480941       18.380499    17.411911  ...     17.734583
# 2      21.279732       21.175544    20.713135  ...     20.925492
# 3      20.004130       19.687705    19.779775  ...     20.672657
# 4      21.300513       22.905330    21.104791  ...     19.409560
# 5      20.161113       20.799373    21.358750  ...     21.089358
# 6      16.205507       16.205507    17.968259  ...     18.079150
# 7      21.051978       21.142438    21.489608  ...     21.456554
# 8      20.956093       21.196232    18.436286  ...     16.436858
# 9      19.156494       19.156494    21.289901  ...     21.509898
#
#    CD8stem_250K_1  CD8stem_300K_2  CD8trans_250K_2  CD8trans_350K_1  \
# 0       22.152181       22.332425        22.055728        22.410025
# 1       19.498693       19.463189        18.763825        17.997173
# 2       21.168424       21.391040        21.140276        21.210811
# 3       19.811251       20.197009        18.886893        20.488517
# 4       23.191467       19.409560        22.334885        23.475775
# 5       19.571862       20.750363        20.770753        20.827993
# 6       16.205507       16.205507        16.205507        16.205507
# 7       20.969946       21.134011        21.167606        21.117271
# 8       20.920069       20.992116        21.467303        20.925160
# 9       19.156494       19.156494        19.156494        19.156494
#
#    Tn_250K_1  Tn_250K_2   pooled_1   pooled_2   pooled_3
# 0  22.475036  22.624466  22.230003  22.068929  21.666248
# 1  19.024778  19.107937  18.589737  19.042832  19.354318
# 2  21.643647  21.769398  21.347664  20.933037  20.733745
# 3  18.886893  18.886893  18.886893  19.886893  18.886893
# 4  22.150570  21.947780  22.467774  22.550826  22.760855
# 5  20.836984  21.047469  20.782791  20.879800  20.679221
# 6  16.205507  19.773114  16.205507  16.205507  16.205507
# 7  21.116658  21.290124  20.891109  21.120224  21.151597
# 8  20.476788  21.016427  20.275338  20.525621  20.706260
# 9  20.883350  20.899179  21.622607  20.944407  20.149087
#
# [10 rows x 42 columns]

# %%
FTIDs = df_sel['id_number'].tolist()

# %%
df_feat_annot = pd.read_csv("../../../../asari-output-RPneg/output_asari_project_31312361/Feature_annotation.tsv",
                           sep = '\t', index_col=0)

# %%
# Select the desired rows and columns from the DataFrame
subset = df_feat_annot.loc[FTIDs, ['mz', 'rtime', 'apex(scan number)']]
# drop duplicates
subset_dd = subset.drop_duplicates() 
# Convert the subset to a dictionary with row-wise orientation
target_dict = subset_dd.to_dict(orient='index')

# %%
target_dict
# Out:
# {'F10088': {'mz': 706.5006714,
#   'rtime': 376.5235142,
#   'apex(scan number)': 1736},
#  'F10378': {'mz': 798.5261841,
#   'rtime': 343.4068623,
#   'apex(scan number)': 1576},
#  'F10486': {'mz': 734.531517, 'rtime': 414.8943499, 'apex(scan number)': 1917},
#  'F11304': {'mz': 768.5214996, 'rtime': 22.23502574, 'apex(scan number)': 98},
#  'F11498': {'mz': 810.5288544, 'rtime': 29.18410728, 'apex(scan number)': 130},
#  'F11849': {'mz': 772.5473633,
#   'rtime': 326.2512226,
#   'apex(scan number)': 1493},
#  'F12641': {'mz': 820.513134, 'rtime': 305.2302092, 'apex(scan number)': 1393},
#  'F12819': {'mz': 748.5130005, 'rtime': 176.9801149, 'apex(scan number)': 789},
#  'F12928': {'mz': 784.548584, 'rtime': 444.1771317, 'apex(scan number)': 2057},
#  'F13113': {'mz': 832.5114441,
#   'rtime': 306.8813714,
#   'apex(scan number)': 1401},
#  'F13352': {'mz': 788.5444641,
#   'rtime': 303.1665999,
#   'apex(scan number)': 1383},
#  'F13368': {'mz': 788.57901, 'rtime': 373.2147096, 'apex(scan number)': 1720},
#  'F13395': {'mz': 826.5589447,
#   'rtime': 382.5181185,
#   'apex(scan number)': 1765},
#  'F13804': {'mz': 836.5431061,
#   'rtime': 308.9440999,
#   'apex(scan number)': 1411},
#  'F13805': {'mz': 870.6230164,
#   'rtime': 303.1665999,
#   'apex(scan number)': 1383},
#  'F14097': {'mz': 838.5559387,
#   'rtime': 341.9613412,
#   'apex(scan number)': 1569},
#  'F14243': {'mz': 876.5717087,
#   'rtime': 369.4913012,
#   'apex(scan number)': 1702},
#  'F14588': {'mz': 880.61026, 'rtime': 346.5099428, 'apex(scan number)': 1591},
#  'F14998': {'mz': 846.5271072,
#   'rtime': 309.3571355,
#   'apex(scan number)': 1413},
#  'F15086': {'mz': 846.6229858, 'rtime': 421.526888, 'apex(scan number)': 1949},
#  'F15244': {'mz': 848.5422516,
#   'rtime': 342.5807985,
#   'apex(scan number)': 1572},
#  'F15491': {'mz': 890.5910416,
#   'rtime': 316.7011344,
#   'apex(scan number)': 1447},
#  'F15637': {'mz': 892.6095352,
#   'rtime': 354.9934881,
#   'apex(scan number)': 1632},
#  'F15666': {'mz': 852.5762634,
#   'rtime': 261.2992009,
#   'apex(scan number)': 1183},
#  'F16120': {'mz': 896.6377716,
#   'rtime': 402.8059366,
#   'apex(scan number)': 1860},
#  'F16127': {'mz': 854.6282654, 'rtime': 213.9793709, 'apex(scan number)': 962},
#  'F1614': {'mz': 482.289032, 'rtime': 207.0361458, 'apex(scan number)': 930},
#  'F16286': {'mz': 856.5115967,
#   'rtime': 303.3728419,
#   'apex(scan number)': 1384},
#  'F16535': {'mz': 858.5270767,
#   'rtime': 306.6752931,
#   'apex(scan number)': 1400},
#  'F17235': {'mz': 864.5757294,
#   'rtime': 301.7200526,
#   'apex(scan number)': 1376},
#  'F1779': {'mz': 524.2982025, 'rtime': 96.46787131, 'apex(scan number)': 429},
#  'F3138': {'mz': 540.3304749, 'rtime': 70.18314622, 'apex(scan number)': 312},
#  'F3712': {'mz': 498.2842712, 'rtime': 33.7166375, 'apex(scan number)': 151},
#  'F5343': {'mz': 662.4425735, 'rtime': 206.4148905, 'apex(scan number)': 927},
#  'F5983': {'mz': 572.2992706, 'rtime': 217.4495763, 'apex(scan number)': 978},
#  'F7394': {'mz': 678.4376984, 'rtime': 208.1129785, 'apex(scan number)': 935},
#  'F9383': {'mz': 692.4490967, 'rtime': 117.5625151, 'apex(scan number)': 522},
#  'F9458': {'mz': 756.5157776, 'rtime': 408.8880167, 'apex(scan number)': 1888},
#  'F9693': {'mz': 794.5301132, 'rtime': 334.5268382, 'apex(scan number)': 1533},
#  'F9945': {'mz': 728.4467087, 'rtime': 196.421451, 'apex(scan number)': 881}}

# %%
list(target_dict.items())[0]
# Out:
# ('F10088',
#  {'mz': 706.5006714, 'rtime': 376.5235142, 'apex(scan number)': 1736})

# %% [markdown]
# ## get potential precursor from multiple files

# %%
res_dict = {}
for exp in exps:
    for k,v in target_dict.items():
        spectra = get_potental_precursor_from_exp(exp, 
                              min_scan_number = v['apex(scan number)']-2000, 
                              max_scan_number = v['apex(scan number)']+2000, 
                              min_mz = np.floor(v['mz']), 
                              max_mz = np.ceil(v['mz']), 
                              ms_level=2)
        res_dict[k] = spectra
# Out:
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False

# %%
res_dict
# Out:
# {'F10088': [<__main__.Spectrum object with native ID 1041 at 0x7f927f4e6f10>,
#   <__main__.Spectrum object with native ID 1043 at 0x7f927f62b580>,
#   <__main__.Spectrum object with native ID 1250 at 0x7f927f618220>,
#   <__main__.Spectrum object with native ID 1252 at 0x7f927d106a90>,
#   <__main__.Spectrum object with native ID 1290 at 0x7f927f6769a0>,
#   <__main__.Spectrum object with native ID 1292 at 0x7f92815dde50>,
#   <__main__.Spectrum object with native ID 1371 at 0x7f927f4feb50>,
#   <__main__.Spectrum object with native ID 1373 at 0x7f92815ddcd0>],
#  'F10378': [<__main__.Spectrum object with native ID 2561 at 0x7f927f4e6fa0>,
#   <__main__.Spectrum object with native ID 2563 at 0x7f927f63f0d0>],
#  'F10486': [<__main__.Spectrum object with native ID 1141 at 0x7f927e8a5130>,
#   <__main__.Spectrum object with native ID 1143 at 0x7f927f62b2e0>,
#   <__main__.Spectrum object with native ID 1160 at 0x7f927f4e6c40>,
#   <__main__.Spectrum object with native ID 1162 at 0x7f927f618a60>,
#   <__main__.Spectrum object with native ID 1181 at 0x7f927f4e6d00>,
#   <__main__.Spectrum object with native ID 1183 at 0x7f92815dde20>,
#   <__main__.Spectrum object with native ID 1201 at 0x7f927f618310>,
#   <__main__.Spectrum object with native ID 1203 at 0x7f927f4e67c0>,
#   <__main__.Spectrum object with native ID 1221 at 0x7f927f63f820>,
#   <__main__.Spectrum object with native ID 1223 at 0x7f927f62b250>,
#   <__main__.Spectrum object with native ID 1241 at 0x7f927f618610>,
#   <__main__.Spectrum object with native ID 1243 at 0x7f92815ddf70>,
#   <__main__.Spectrum object with native ID 1261 at 0x7f927f62b880>,
#   <__main__.Spectrum object with native ID 1263 at 0x7f927f63f340>,
#   <__main__.Spectrum object with native ID 1296 at 0x7f927f62bac0>,
#   <__main__.Spectrum object with native ID 1298 at 0x7f927ff8e340>,
#   <__main__.Spectrum object with native ID 1386 at 0x7f927d1599d0>,
#   <__main__.Spectrum object with native ID 1388 at 0x7f927f618d90>,
#   <__main__.Spectrum object with native ID 1405 at 0x7f927f618100>,
#   <__main__.Spectrum object with native ID 1407 at 0x7f927f618d30>,
#   <__main__.Spectrum object with native ID 1436 at 0x7f927f63f1f0>,
#   <__main__.Spectrum object with native ID 1438 at 0x7f927f62b5e0>,
#   <__main__.Spectrum object with native ID 1455 at 0x7f927f63f670>,
#   <__main__.Spectrum object with native ID 1457 at 0x7f927f63f190>,
#   <__main__.Spectrum object with native ID 1540 at 0x7f927f63f4c0>,
#   <__main__.Spectrum object with native ID 1542 at 0x7f927f6189d0>,
#   <__main__.Spectrum object with native ID 1560 at 0x7f927f62beb0>,
#   <__main__.Spectrum object with native ID 1562 at 0x7f927f62b640>],
#  'F11304': [],
#  'F11498': [<__main__.Spectrum object with native ID 1980 at 0x7f92815dd910>,
#   <__main__.Spectrum object with native ID 1982 at 0x7f92815ddfa0>,
#   <__main__.Spectrum object with native ID 2000 at 0x7f927f62b610>,
#   <__main__.Spectrum object with native ID 2002 at 0x7f927f63f6a0>,
#   <__main__.Spectrum object with native ID 2020 at 0x7f927f618820>,
#   <__main__.Spectrum object with native ID 2022 at 0x7f927f63f1c0>,
#   <__main__.Spectrum object with native ID 2041 at 0x7f927f618bb0>,
#   <__main__.Spectrum object with native ID 2043 at 0x7f927f63f490>],
#  'F11849': [],
#  'F12641': [<__main__.Spectrum object with native ID 1346 at 0x7f92815ddd90>,
#   <__main__.Spectrum object with native ID 1348 at 0x7f927f63f910>],
#  'F12819': [<__main__.Spectrum object with native ID 2386 at 0x7f927f62bbb0>,
#   <__main__.Spectrum object with native ID 2388 at 0x7f927f62bca0>,
#   <__main__.Spectrum object with native ID 2405 at 0x7f927d11fee0>,
#   <__main__.Spectrum object with native ID 2407 at 0x7f927f4fed00>,
#   <__main__.Spectrum object with native ID 2425 at 0x7f927f6a49d0>,
#   <__main__.Spectrum object with native ID 2427 at 0x7f927f6a4c70>],
#  'F12928': [],
#  'F13113': [<__main__.Spectrum object with native ID 2485 at 0x7f927f62bd30>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f927f62bfd0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f927f62ba30>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f927f6586a0>,
#   <__main__.Spectrum object with native ID 2975 at 0x7f927f658610>,
#   <__main__.Spectrum object with native ID 2977 at 0x7f927f4fe7c0>],
#  'F13352': [],
#  'F13368': [],
#  'F13395': [<__main__.Spectrum object with native ID 2751 at 0x7f92815ddd30>,
#   <__main__.Spectrum object with native ID 2753 at 0x7f927f62bf70>],
#  'F13804': [],
#  'F13805': [],
#  'F14097': [],
#  'F14243': [],
#  'F14588': [],
#  'F14998': [],
#  'F15086': [],
#  'F15244': [],
#  'F15491': [],
#  'F15637': [],
#  'F15666': [],
#  'F16120': [],
#  'F16127': [],
#  'F1614': [],
#  'F16286': [],
#  'F16535': [],
#  'F17235': [],
#  'F1779': [],
#  'F3138': [<__main__.Spectrum object with native ID 406 at 0x7f927f4e6a90>,
#   <__main__.Spectrum object with native ID 408 at 0x7f927f63f9d0>],
#  'F3712': [],
#  'F5343': [<__main__.Spectrum object with native ID 1475 at 0x7f927f6764c0>,
#   <__main__.Spectrum object with native ID 1477 at 0x7f927f63f2b0>],
#  'F5983': [],
#  'F7394': [],
#  'F9383': [<__main__.Spectrum object with native ID 1966 at 0x7f927f4fe970>,
#   <__main__.Spectrum object with native ID 1968 at 0x7f927f63f2e0>,
#   <__main__.Spectrum object with native ID 1986 at 0x7f927f63f370>,
#   <__main__.Spectrum object with native ID 1988 at 0x7f927f63f640>],
#  'F9458': [],
#  'F9693': [<__main__.Spectrum object with native ID 2346 at 0x7f927f6580d0>,
#   <__main__.Spectrum object with native ID 2348 at 0x7f927f4e6c70>,
#   <__main__.Spectrum object with native ID 2365 at 0x7f927f618e20>,
#   <__main__.Spectrum object with native ID 2367 at 0x7f927f618ee0>],
#  'F9945': []}

# %%
# items that don't have spectra associated
[k for k,v in res_dict.items() if len(v) == 0 ]
# Out:
# ['F11304',
#  'F11849',
#  'F12928',
#  'F13352',
#  'F13368',
#  'F13804',
#  'F13805',
#  'F14097',
#  'F14243',
#  'F14588',
#  'F14998',
#  'F15086',
#  'F15244',
#  'F15491',
#  'F15637',
#  'F15666',
#  'F16120',
#  'F16127',
#  'F1614',
#  'F16286',
#  'F16535',
#  'F17235',
#  'F1779',
#  'F3712',
#  'F5983',
#  'F7394',
#  'F9458',
#  'F9945']

# %%
res_dict_clean = {k:v for k,v in res_dict.items() if len(v) != 0}

# %%
res_dict_clean
# Out:
# {'F10088': [<__main__.Spectrum object with native ID 1041 at 0x7f927f4e6f10>,
#   <__main__.Spectrum object with native ID 1043 at 0x7f927f62b580>,
#   <__main__.Spectrum object with native ID 1250 at 0x7f927f618220>,
#   <__main__.Spectrum object with native ID 1252 at 0x7f927d106a90>,
#   <__main__.Spectrum object with native ID 1290 at 0x7f927f6769a0>,
#   <__main__.Spectrum object with native ID 1292 at 0x7f92815dde50>,
#   <__main__.Spectrum object with native ID 1371 at 0x7f927f4feb50>,
#   <__main__.Spectrum object with native ID 1373 at 0x7f92815ddcd0>],
#  'F10378': [<__main__.Spectrum object with native ID 2561 at 0x7f927f4e6fa0>,
#   <__main__.Spectrum object with native ID 2563 at 0x7f927f63f0d0>],
#  'F10486': [<__main__.Spectrum object with native ID 1141 at 0x7f927e8a5130>,
#   <__main__.Spectrum object with native ID 1143 at 0x7f927f62b2e0>,
#   <__main__.Spectrum object with native ID 1160 at 0x7f927f4e6c40>,
#   <__main__.Spectrum object with native ID 1162 at 0x7f927f618a60>,
#   <__main__.Spectrum object with native ID 1181 at 0x7f927f4e6d00>,
#   <__main__.Spectrum object with native ID 1183 at 0x7f92815dde20>,
#   <__main__.Spectrum object with native ID 1201 at 0x7f927f618310>,
#   <__main__.Spectrum object with native ID 1203 at 0x7f927f4e67c0>,
#   <__main__.Spectrum object with native ID 1221 at 0x7f927f63f820>,
#   <__main__.Spectrum object with native ID 1223 at 0x7f927f62b250>,
#   <__main__.Spectrum object with native ID 1241 at 0x7f927f618610>,
#   <__main__.Spectrum object with native ID 1243 at 0x7f92815ddf70>,
#   <__main__.Spectrum object with native ID 1261 at 0x7f927f62b880>,
#   <__main__.Spectrum object with native ID 1263 at 0x7f927f63f340>,
#   <__main__.Spectrum object with native ID 1296 at 0x7f927f62bac0>,
#   <__main__.Spectrum object with native ID 1298 at 0x7f927ff8e340>,
#   <__main__.Spectrum object with native ID 1386 at 0x7f927d1599d0>,
#   <__main__.Spectrum object with native ID 1388 at 0x7f927f618d90>,
#   <__main__.Spectrum object with native ID 1405 at 0x7f927f618100>,
#   <__main__.Spectrum object with native ID 1407 at 0x7f927f618d30>,
#   <__main__.Spectrum object with native ID 1436 at 0x7f927f63f1f0>,
#   <__main__.Spectrum object with native ID 1438 at 0x7f927f62b5e0>,
#   <__main__.Spectrum object with native ID 1455 at 0x7f927f63f670>,
#   <__main__.Spectrum object with native ID 1457 at 0x7f927f63f190>,
#   <__main__.Spectrum object with native ID 1540 at 0x7f927f63f4c0>,
#   <__main__.Spectrum object with native ID 1542 at 0x7f927f6189d0>,
#   <__main__.Spectrum object with native ID 1560 at 0x7f927f62beb0>,
#   <__main__.Spectrum object with native ID 1562 at 0x7f927f62b640>],
#  'F11498': [<__main__.Spectrum object with native ID 1980 at 0x7f92815dd910>,
#   <__main__.Spectrum object with native ID 1982 at 0x7f92815ddfa0>,
#   <__main__.Spectrum object with native ID 2000 at 0x7f927f62b610>,
#   <__main__.Spectrum object with native ID 2002 at 0x7f927f63f6a0>,
#   <__main__.Spectrum object with native ID 2020 at 0x7f927f618820>,
#   <__main__.Spectrum object with native ID 2022 at 0x7f927f63f1c0>,
#   <__main__.Spectrum object with native ID 2041 at 0x7f927f618bb0>,
#   <__main__.Spectrum object with native ID 2043 at 0x7f927f63f490>],
#  'F12641': [<__main__.Spectrum object with native ID 1346 at 0x7f92815ddd90>,
#   <__main__.Spectrum object with native ID 1348 at 0x7f927f63f910>],
#  'F12819': [<__main__.Spectrum object with native ID 2386 at 0x7f927f62bbb0>,
#   <__main__.Spectrum object with native ID 2388 at 0x7f927f62bca0>,
#   <__main__.Spectrum object with native ID 2405 at 0x7f927d11fee0>,
#   <__main__.Spectrum object with native ID 2407 at 0x7f927f4fed00>,
#   <__main__.Spectrum object with native ID 2425 at 0x7f927f6a49d0>,
#   <__main__.Spectrum object with native ID 2427 at 0x7f927f6a4c70>],
#  'F13113': [<__main__.Spectrum object with native ID 2485 at 0x7f927f62bd30>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f927f62bfd0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f927f62ba30>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f927f6586a0>,
#   <__main__.Spectrum object with native ID 2975 at 0x7f927f658610>,
#   <__main__.Spectrum object with native ID 2977 at 0x7f927f4fe7c0>],
#  'F13395': [<__main__.Spectrum object with native ID 2751 at 0x7f92815ddd30>,
#   <__main__.Spectrum object with native ID 2753 at 0x7f927f62bf70>],
#  'F3138': [<__main__.Spectrum object with native ID 406 at 0x7f927f4e6a90>,
#   <__main__.Spectrum object with native ID 408 at 0x7f927f63f9d0>],
#  'F5343': [<__main__.Spectrum object with native ID 1475 at 0x7f927f6764c0>,
#   <__main__.Spectrum object with native ID 1477 at 0x7f927f63f2b0>],
#  'F9383': [<__main__.Spectrum object with native ID 1966 at 0x7f927f4fe970>,
#   <__main__.Spectrum object with native ID 1968 at 0x7f927f63f2e0>,
#   <__main__.Spectrum object with native ID 1986 at 0x7f927f63f370>,
#   <__main__.Spectrum object with native ID 1988 at 0x7f927f63f640>],
#  'F9693': [<__main__.Spectrum object with native ID 2346 at 0x7f927f6580d0>,
#   <__main__.Spectrum object with native ID 2348 at 0x7f927f4e6c70>,
#   <__main__.Spectrum object with native ID 2365 at 0x7f927f618e20>,
#   <__main__.Spectrum object with native ID 2367 at 0x7f927f618ee0>]}

# %%
# this function only works for situation where you look at charge state = 1
def search_NL(spectra,
              NL_mz = 87.03124,
              ppm = 1000):
    res_data = []

    for spec in spectra:
        selected_precursor_mz = spec.selected_precursors[0]['mz'] # this m/z will not be exactly the precursor m/z
        sel_mz = [mz for mz in spec.mz if abs(mz - selected_precursor_mz) < np.ceil(NL_mz)]

        for mz in sel_mz:
            calc_ppm = abs(((selected_precursor_mz - mz) - NL_mz)*1000000/NL_mz)
            if calc_ppm < ppm:
                print(calc_ppm)
                res_data.append(spec)
                break
    return res_data

# %%
res_dict = {}
for FTID, spectra in res_dict_clean.items():
    res_dict.update({FTID: search_NL(spectra)})

# %%
res_dict
# Out:
# {'F10088': [],
#  'F10378': [],
#  'F10486': [],
#  'F11498': [],
#  'F12641': [],
#  'F12819': [],
#  'F13113': [],
#  'F13395': [],
#  'F3138': [],
#  'F5343': [],
#  'F9383': [],
#  'F9693': []}

# %% [markdown]
# # plot accordingly

# %%
res_dict_clean.keys()
# Out:
# dict_keys(['F10088', 'F10378', 'F10486', 'F11498', 'F12641', 'F12819', 'F13113', 'F13395', 'F3138', 'F5343', 'F9383', 'F9693'])

# %%
df_sel.index = df_sel['id_number']

# %%
df_sel.columns[0:6]
# Out:
# Index(['id_number', 'X.M.H.', 'Species.Shorthand', 'Formula', 'Neutral_Mass',
#        'Common.Name'],
#       dtype='object')

# %%
for FTID in res_dict_clean.keys():
    plot_spectra(spectra = res_dict_clean[FTID], 
                 save_figure=True,
                 output_path=f"./data/output/{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}/",
                 label = f"{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}"
                 )
