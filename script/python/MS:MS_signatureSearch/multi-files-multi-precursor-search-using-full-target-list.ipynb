# %% [markdown]
# # Extract the MS2 scan and do signature neutral loss search
# - run multiple files
# - need to define a precursor target list & scan range (let's just try to do more inclusive one)

# %%
# !pip install pymzml
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt
import pymzml
import os
import pandas as pd
import sys

# %%
sys.path.append('../pyutils/')  # add the second parent directory
from searchMS2 import *

# %%
# spectrum.selected_precursors
# [{'mz': 417.320373535156, 'charge': 1, 'precursor id': '2'}]

# %%
dir_path = "../../../../MS_MS_raw_mzML/AX_RPneg_TDcells/mzML/"
files_and_dirs = os.listdir(dir_path)

# Get the full path for each file/directory in the list
infiles = [os.path.join(dir_path, file) for file in files_and_dirs]

# %%
exps = []
for infile in infiles:
    exps.append(pymzml.run.Reader(infile))
# Out:
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False

# %% [markdown]
# ## Basic information - using the first instance

# %%
exp = pymzml.run.Reader(infiles[0])
# Out:
# [Warning] Not index found and build_index_from_scratch is False

# %%
# How many spectra
exp.get_spectrum_count()
# Out:
# 4008

# %%
exp.ms_precisions # ms-level 1: ppm 5; ms-level 2: ppm 20?
# Out:
# {None: 0.0001, 0: 0.0001, 1: 5e-06, 2: 2e-05}

# %% [markdown]
# ##### summary
# - a probably 12 min run (720 secs) for 4008 scans
# - 0.17964 second/scan

# %% [markdown]
# ## Load target list

# %%
df_sel = pd.read_csv("./data/input/targeted_extraction__Feature_table.tsv", sep = '\t')

# %%
df_sel.head(10)
# Out:
#    query_target id_number        mz   rtime  rtime_left_base  \
# 0    482.288282     F1614  482.2890  207.04           204.92
# 1    498.283197     F3712  498.2843   33.72            32.23
# 2    524.298847     F1779  524.2982   96.47            93.85
# 3    538.350882     F3031  538.3514  107.59           104.85
# 4    540.330147     F3138  540.3305   70.18            67.44
# 5    552.330147     F4105  552.3305   61.26            58.52
# 6    554.345797     F4190  554.3468   82.07            79.32
# 7    566.309412     F5441  566.3086  162.45           159.81
# 8    568.361447     F5580  568.3622  113.77           111.02
# 9    572.298847     F5983  572.2993  217.45           214.85
#
#    rtime_right_base  parent_masstrack_id  peak_area  cSelectivity  \
# 0            209.41                 1335    4365548          0.88
# 1             36.32                 1567   18072147          1.00
# 2             99.13                 1928   36918657          0.76
# 3            110.34                 2126   30389790          0.92
# 4             72.92                 2147   29371349          0.95
# 5             64.01                 2291   54801491          1.00
# 6             84.58                 2315  218470611          0.58
# 7            165.13                 2486   11584313          1.00
# 8            116.47                 2517   32860249          0.93
# 9            219.84                 2580   25336616          1.00
#
#    goodness_fitting  ...  MT_20230308_012  MT_20230308_014  MT_20230308_016  \
# 0              0.85  ...           151268            66061           548649
# 1              0.94  ...           702748           621143          2266499
# 2              0.97  ...          2827464          2817111          2754368
# 3              0.98  ...                0                0                0
# 4              0.98  ...          2352009          2308541                0
# 5              0.99  ...                0                0                0
# 6              0.95  ...                0                0                0
# 7              0.99  ...                0                0          2694084
# 8              0.98  ...                0                0                0
# 9              0.94  ...          1290411          1450712          3675461
#
#    MT_20230308_018  MT_20230308_020  MT_20230308_022  MT_20230308_024  \
# 0           448802           198916           441632           844487
# 1           942310          1587450          1069759          1205834
# 2          2156389          2912621          2697065          2971851
# 3                0                0                0                0
# 4                0                0                0                0
# 5                0                0                0                0
# 6                0                0                0                0
# 7                0          1992950                0          1742897
# 8                0                0                0                0
# 9          1596170          2193715          1389912          2101354
#
#    MT_20230308_026  MT_20230308_028  MT_20230308_030
# 0           167207            43418           395143
# 1                0                0          1426358
# 2          3236482          2724970          3001170
# 3                0                0                0
# 4          2322796          2729822                0
# 5                0                0                0
# 6                0                0                0
# 7                0                0          2018356
# 8                0                0                0
# 9                0          1530704          2716537
#
# [10 rows x 32 columns]

# %%
FTIDs = df_sel['id_number'].tolist()

# %%
df_feat_annot = pd.read_csv("../../../../asari-output-RPneg/output_asari_project_31312361/Feature_annotation.tsv",
                           sep = '\t', index_col=0)

# %%
# Select the desired rows and columns from the DataFrame
subset = df_feat_annot.loc[FTIDs, ['mz', 'rtime', 'apex(scan number)']]
# drop duplicates
subset_dd = subset.drop_duplicates() 
# Convert the subset to a dictionary with row-wise orientation
target_dict = subset_dd.to_dict(orient='index')

# %%
target_dict
# Out:
# {'F1614': {'mz': 482.289032, 'rtime': 207.0361458, 'apex(scan number)': 930},
#  'F3712': {'mz': 498.2842712, 'rtime': 33.7166375, 'apex(scan number)': 151},
#  'F1779': {'mz': 524.2982025, 'rtime': 96.46787131, 'apex(scan number)': 429},
#  'F3031': {'mz': 538.3514099, 'rtime': 107.5941878, 'apex(scan number)': 478},
#  'F3138': {'mz': 540.3304749, 'rtime': 70.18314622, 'apex(scan number)': 312},
#  'F4105': {'mz': 552.3305359, 'rtime': 61.26445373, 'apex(scan number)': 273},
#  'F4190': {'mz': 554.3468018, 'rtime': 82.06768434, 'apex(scan number)': 364},
#  'F5441': {'mz': 566.3086395, 'rtime': 162.4463086, 'apex(scan number)': 723},
#  'F5580': {'mz': 568.3622437, 'rtime': 113.7691743, 'apex(scan number)': 505},
#  'F5983': {'mz': 572.2992706, 'rtime': 217.4495763, 'apex(scan number)': 978},
#  'F6287': {'mz': 576.3304749, 'rtime': 53.03482256, 'apex(scan number)': 237},
#  'F6579': {'mz': 578.3467102, 'rtime': 69.72456917, 'apex(scan number)': 310},
#  'F6913': {'mz': 580.3623352, 'rtime': 89.28646261, 'apex(scan number)': 396},
#  'F7086': {'mz': 582.3782959, 'rtime': 131.6227922, 'apex(scan number)': 586},
#  'F6328': {'mz': 608.3935394, 'rtime': 151.6224779, 'apex(scan number)': 675},
#  'F7618': {'mz': 648.3866882, 'rtime': 82.75293587, 'apex(scan number)': 367},
#  'F5337': {'mz': 662.400177, 'rtime': 707.0211632, 'apex(scan number)': 3267},
#  'F5343': {'mz': 662.4425735, 'rtime': 206.4148905, 'apex(scan number)': 927},
#  'F7394': {'mz': 678.4376984, 'rtime': 208.1129785, 'apex(scan number)': 935},
#  'F9383': {'mz': 692.4490967, 'rtime': 117.5625151, 'apex(scan number)': 522},
#  'F10088': {'mz': 706.5006714,
#   'rtime': 376.5235142,
#   'apex(scan number)': 1736},
#  'F12237': {'mz': 720.5151672,
#   'rtime': 308.7376721,
#   'apex(scan number)': 1410},
#  'F9945': {'mz': 728.4467087, 'rtime': 196.421451, 'apex(scan number)': 881},
#  'F10486': {'mz': 734.531517, 'rtime': 414.8943499, 'apex(scan number)': 1917},
#  'F11972': {'mz': 742.502533, 'rtime': 271.2273671, 'apex(scan number)': 1231},
#  'F12271': {'mz': 744.519165, 'rtime': 21.19735521, 'apex(scan number)': 93},
#  'F12819': {'mz': 748.5130005, 'rtime': 176.9801149, 'apex(scan number)': 789},
#  'F9458': {'mz': 756.5157776, 'rtime': 408.8880167, 'apex(scan number)': 1888},
#  'F9861': {'mz': 758.53479, 'rtime': 240.3464581, 'apex(scan number)': 1085},
#  'F10386': {'mz': 762.5637817,
#   'rtime': 446.2436384,
#   'apex(scan number)': 2067},
#  'F11014': {'mz': 766.5036621,
#   'rtime': 263.3636961,
#   'apex(scan number)': 1193},
#  'F11304': {'mz': 768.5214996, 'rtime': 22.23502574, 'apex(scan number)': 98},
#  'F11681': {'mz': 770.5342865,
#   'rtime': 301.9265967,
#   'apex(scan number)': 1377},
#  'F11849': {'mz': 772.5473633,
#   'rtime': 326.2512226,
#   'apex(scan number)': 1493},
#  'F12086': {'mz': 774.5662231, 'rtime': 90.8078912, 'apex(scan number)': 403},
#  'F12299': {'mz': 776.5812988,
#   'rtime': 405.4210621,
#   'apex(scan number)': 1872},
#  'F12928': {'mz': 784.548584, 'rtime': 444.1771317, 'apex(scan number)': 2057},
#  'F13180': {'mz': 786.5296631, 'rtime': 89.50345185, 'apex(scan number)': 397},
#  'F13184': {'mz': 786.5659332,
#   'rtime': 329.7646807,
#   'apex(scan number)': 1510},
#  'F13352': {'mz': 788.5444641,
#   'rtime': 303.1665999,
#   'apex(scan number)': 1383},
#  'F13368': {'mz': 788.57901, 'rtime': 373.2147096, 'apex(scan number)': 1720},
#  'F13523': {'mz': 790.5600739,
#   'rtime': 331.8347005,
#   'apex(scan number)': 1520},
#  'F13545': {'mz': 790.6001205,
#   'rtime': 425.2911508,
#   'apex(scan number)': 1967},
#  'F9678': {'mz': 794.4962463, 'rtime': 258.3987786, 'apex(scan number)': 1169},
#  'F9693': {'mz': 794.5301132, 'rtime': 334.5268382, 'apex(scan number)': 1533},
#  'F9994': {'mz': 796.5134125, 'rtime': 69.72456917, 'apex(scan number)': 310},
#  'F10004': {'mz': 796.5466614,
#   'rtime': 373.0082339,
#   'apex(scan number)': 1719},
#  'F10378': {'mz': 798.5261841,
#   'rtime': 343.4068623,
#   'apex(scan number)': 1576},
#  'F10628': {'mz': 800.5475769, 'rtime': 89.50345185, 'apex(scan number)': 397},
#  'F10649': {'mz': 800.5813293,
#   'rtime': 363.0737238,
#   'apex(scan number)': 1671},
#  'F10790': {'mz': 802.5606079,
#   'rtime': 319.8384093,
#   'apex(scan number)': 1462},
#  'F10809': {'mz': 802.5965881,
#   'rtime': 373.6276568,
#   'apex(scan number)': 1722},
#  'F10998': {'mz': 804.5791779,
#   'rtime': 354.9934881,
#   'apex(scan number)': 1632},
#  'F11006': {'mz': 804.6121368, 'rtime': 129.3614733, 'apex(scan number)': 576},
#  'F11498': {'mz': 810.5288544, 'rtime': 29.18410728, 'apex(scan number)': 130},
#  'F11746': {'mz': 812.5441589, 'rtime': 289.676302, 'apex(scan number)': 1320},
#  'F12027': {'mz': 814.5606995, 'rtime': 90.8078912, 'apex(scan number)': 403},
#  'F12261': {'mz': 816.5760803,
#   'rtime': 253.2275759,
#   'apex(scan number)': 1145},
#  'F12389': {'mz': 818.5359421, 'rtime': 21.81872176, 'apex(scan number)': 96},
#  'F12441': {'mz': 818.5917053,
#   'rtime': 304.4058632,
#   'apex(scan number)': 1389},
#  'F12641': {'mz': 820.513134, 'rtime': 305.2302092, 'apex(scan number)': 1393},
#  'F12902': {'mz': 822.5664368,
#   'rtime': 302.9604226,
#   'apex(scan number)': 1382},
#  'F13048': {'mz': 824.5447388,
#   'rtime': 302.1349513,
#   'apex(scan number)': 1378},
#  'F13079': {'mz': 824.5801697,
#   'rtime': 429.4166962,
#   'apex(scan number)': 1986},
#  'F13395': {'mz': 826.5589447,
#   'rtime': 382.5181185,
#   'apex(scan number)': 1765},
#  'F13488': {'mz': 826.5979919, 'rtime': 193.3699238, 'apex(scan number)': 867},
#  'F13638': {'mz': 828.5761414, 'rtime': 142.5729514, 'apex(scan number)': 635},
#  'F13658': {'mz': 828.6119995,
#   'rtime': 409.3026678,
#   'apex(scan number)': 1890},
#  'F12900': {'mz': 830.5898438,
#   'rtime': 361.4158748,
#   'apex(scan number)': 1663},
#  'F12910': {'mz': 830.6288452,
#   'rtime': 414.6877067,
#   'apex(scan number)': 1916},
#  'F13113': {'mz': 832.5114441,
#   'rtime': 306.8813714,
#   'apex(scan number)': 1401},
#  'F13132': {'mz': 832.607666, 'rtime': 399.1035194, 'apex(scan number)': 1843},
#  'F13136': {'mz': 832.6459656,
#   'rtime': 429.1991519,
#   'apex(scan number)': 1985},
#  'F13468': {'mz': 834.5291901,
#   'rtime': 262.3327382,
#   'apex(scan number)': 1188},
#  'F13804': {'mz': 836.5431061,
#   'rtime': 308.9440999,
#   'apex(scan number)': 1411},
#  'F14097': {'mz': 838.5559387,
#   'rtime': 341.9613412,
#   'apex(scan number)': 1569},
#  'F14354': {'mz': 840.5755005,
#   'rtime': 250.1761033,
#   'apex(scan number)': 1131},
#  'F14607': {'mz': 842.5911713,
#   'rtime': 256.7160175,
#   'apex(scan number)': 1161},
#  'F14831': {'mz': 844.6073914,
#   'rtime': 302.1349513,
#   'apex(scan number)': 1378},
#  'F14998': {'mz': 846.5271072,
#   'rtime': 309.3571355,
#   'apex(scan number)': 1413},
#  'F15014': {'mz': 846.5629883,
#   'rtime': 366.5939383,
#   'apex(scan number)': 1688},
#  'F15086': {'mz': 846.6229858, 'rtime': 421.526888, 'apex(scan number)': 1949},
#  'F15244': {'mz': 848.5422516,
#   'rtime': 342.5807985,
#   'apex(scan number)': 1572},
#  'F15257': {'mz': 848.5830383,
#   'rtime': 331.8347005,
#   'apex(scan number)': 1520},
#  'F15440': {'mz': 850.5567322,
#   'rtime': 313.6862427,
#   'apex(scan number)': 1433},
#  'F15464': {'mz': 850.5964508, 'rtime': 348.373978, 'apex(scan number)': 1600},
#  'F15666': {'mz': 852.5762634,
#   'rtime': 261.2992009,
#   'apex(scan number)': 1183},
#  'F15734': {'mz': 852.6121521,
#   'rtime': 359.9664691,
#   'apex(scan number)': 1656},
#  'F16070': {'mz': 854.5911865,
#   'rtime': 240.3464581,
#   'apex(scan number)': 1085},
#  'F16127': {'mz': 854.6282654, 'rtime': 213.9793709, 'apex(scan number)': 962},
#  'F16286': {'mz': 856.5115967,
#   'rtime': 303.3728419,
#   'apex(scan number)': 1384},
#  'F16333': {'mz': 856.6064148,
#   'rtime': 393.6629251,
#   'apex(scan number)': 1818},
#  'F16346': {'mz': 856.6429443, 'rtime': 434.851151, 'apex(scan number)': 2012},
#  'F16535': {'mz': 858.5270767,
#   'rtime': 306.6752931,
#   'apex(scan number)': 1400},
#  'F16561': {'mz': 858.620163, 'rtime': 406.9481793, 'apex(scan number)': 1879},
#  'F16926': {'mz': 860.634491, 'rtime': 403.6762697, 'apex(scan number)': 1864},
#  'F17105': {'mz': 862.5597229,
#   'rtime': 281.3455834,
#   'apex(scan number)': 1280},
#  'F17235': {'mz': 864.5757294,
#   'rtime': 301.7200526,
#   'apex(scan number)': 1376},
#  'F17396': {'mz': 866.5913467,
#   'rtime': 255.8434273,
#   'apex(scan number)': 1157},
#  'F17530': {'mz': 868.6070404,
#   'rtime': 275.7692944,
#   'apex(scan number)': 1253},
#  'F13805': {'mz': 870.6230164,
#   'rtime': 303.1665999,
#   'apex(scan number)': 1383},
#  'F13961': {'mz': 872.6395187,
#   'rtime': 429.4166962,
#   'apex(scan number)': 1986},
#  'F14243': {'mz': 876.5717087,
#   'rtime': 369.4913012,
#   'apex(scan number)': 1702},
#  'F14588': {'mz': 880.61026, 'rtime': 346.5099428, 'apex(scan number)': 1591},
#  'F15491': {'mz': 890.5910416,
#   'rtime': 316.7011344,
#   'apex(scan number)': 1447},
#  'F15637': {'mz': 892.6095352,
#   'rtime': 354.9934881,
#   'apex(scan number)': 1632},
#  'F15865': {'mz': 894.6204262,
#   'rtime': 383.5506181,
#   'apex(scan number)': 1770},
#  'F16120': {'mz': 896.6377716,
#   'rtime': 402.8059366,
#   'apex(scan number)': 1860}}

# %%
list(target_dict.items())[0]
# Out:
# ('F1614', {'mz': 482.289032, 'rtime': 207.0361458, 'apex(scan number)': 930})

# %% [markdown]
# ## get potential precursor from multiple files

# %%
res_dict = {}
for exp in exps:
    for k,v in target_dict.items():
        spectra = get_potental_precursor_from_exp(exp, 
                              min_scan_number = v['apex(scan number)']-1000, 
                              max_scan_number = v['apex(scan number)']+1000, 
                              min_mz = np.floor(v['mz']), 
                              max_mz = np.ceil(v['mz']), 
                              ms_level=2)
        res_dict[k] = spectra
# Out:
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False
# [Warning] Not index found and build_index_from_scratch is False

# %%
res_dict
# Out:
# {'F1614': [],
#  'F3712': [],
#  'F1779': [],
#  'F3031': [],
#  'F3138': [<__main__.Spectrum object with native ID 406 at 0x7f8975f210a0>,
#   <__main__.Spectrum object with native ID 408 at 0x7f8975f211f0>],
#  'F4105': [],
#  'F4190': [],
#  'F5441': [],
#  'F5580': [],
#  'F5983': [],
#  'F6287': [],
#  'F6579': [],
#  'F6913': [],
#  'F7086': [],
#  'F6328': [<__main__.Spectrum object with native ID 1411 at 0x7f8975f34bb0>,
#   <__main__.Spectrum object with native ID 1413 at 0x7f8976137b20>],
#  'F7618': [],
#  'F5337': [],
#  'F5343': [<__main__.Spectrum object with native ID 1475 at 0x7f8975f487f0>,
#   <__main__.Spectrum object with native ID 1477 at 0x7f8976116c40>],
#  'F7394': [],
#  'F9383': [],
#  'F10088': [<__main__.Spectrum object with native ID 1041 at 0x7f8976116a90>,
#   <__main__.Spectrum object with native ID 1043 at 0x7f8976116640>,
#   <__main__.Spectrum object with native ID 1250 at 0x7f8975f34b80>,
#   <__main__.Spectrum object with native ID 1252 at 0x7f8976129d90>,
#   <__main__.Spectrum object with native ID 1290 at 0x7f8975f34760>,
#   <__main__.Spectrum object with native ID 1292 at 0x7f8976129ee0>,
#   <__main__.Spectrum object with native ID 1371 at 0x7f8975f21520>,
#   <__main__.Spectrum object with native ID 1373 at 0x7f8975f34f10>],
#  'F12237': [<__main__.Spectrum object with native ID 2176 at 0x7f8975f48280>,
#   <__main__.Spectrum object with native ID 2178 at 0x7f8975f48e80>,
#   <__main__.Spectrum object with native ID 2195 at 0x7f8975f342b0>,
#   <__main__.Spectrum object with native ID 2197 at 0x7f8975f346d0>,
#   <__main__.Spectrum object with native ID 2215 at 0x7f8975f34a30>,
#   <__main__.Spectrum object with native ID 2217 at 0x7f8976137220>],
#  'F9945': [],
#  'F10486': [<__main__.Spectrum object with native ID 1141 at 0x7f8975f486d0>,
#   <__main__.Spectrum object with native ID 1143 at 0x7f8976116ee0>,
#   <__main__.Spectrum object with native ID 1160 at 0x7f8976116f10>,
#   <__main__.Spectrum object with native ID 1162 at 0x7f8975f21790>,
#   <__main__.Spectrum object with native ID 1181 at 0x7f8975f21f40>,
#   <__main__.Spectrum object with native ID 1183 at 0x7f89761375e0>,
#   <__main__.Spectrum object with native ID 1201 at 0x7f89761377f0>,
#   <__main__.Spectrum object with native ID 1203 at 0x7f8975f217f0>,
#   <__main__.Spectrum object with native ID 1221 at 0x7f8976137eb0>,
#   <__main__.Spectrum object with native ID 1223 at 0x7f8975f48160>,
#   <__main__.Spectrum object with native ID 1241 at 0x7f89761293a0>,
#   <__main__.Spectrum object with native ID 1243 at 0x7f8976116e20>,
#   <__main__.Spectrum object with native ID 1261 at 0x7f8975f34eb0>,
#   <__main__.Spectrum object with native ID 1263 at 0x7f8975f34b50>,
#   <__main__.Spectrum object with native ID 1296 at 0x7f8975f34790>,
#   <__main__.Spectrum object with native ID 1298 at 0x7f89761292b0>,
#   <__main__.Spectrum object with native ID 1386 at 0x7f8975f21e50>,
#   <__main__.Spectrum object with native ID 1388 at 0x7f8976129190>,
#   <__main__.Spectrum object with native ID 1405 at 0x7f8976129c10>,
#   <__main__.Spectrum object with native ID 1407 at 0x7f8975f07d90>,
#   <__main__.Spectrum object with native ID 1436 at 0x7f8976129280>,
#   <__main__.Spectrum object with native ID 1438 at 0x7f8975f07160>,
#   <__main__.Spectrum object with native ID 1455 at 0x7f8975f07e50>,
#   <__main__.Spectrum object with native ID 1457 at 0x7f8975f070d0>,
#   <__main__.Spectrum object with native ID 1540 at 0x7f8976129040>,
#   <__main__.Spectrum object with native ID 1542 at 0x7f8975f07eb0>,
#   <__main__.Spectrum object with native ID 1560 at 0x7f8976137d00>,
#   <__main__.Spectrum object with native ID 1562 at 0x7f8975f071f0>],
#  'F11972': [],
#  'F12271': [],
#  'F12819': [],
#  'F9458': [],
#  'F9861': [],
#  'F10386': [<__main__.Spectrum object with native ID 1666 at 0x7f89761165e0>,
#   <__main__.Spectrum object with native ID 1668 at 0x7f8976116310>,
#   <__main__.Spectrum object with native ID 1690 at 0x7f8975f21400>,
#   <__main__.Spectrum object with native ID 1692 at 0x7f8976116040>],
#  'F11014': [<__main__.Spectrum object with native ID 851 at 0x7f8975f48400>,
#   <__main__.Spectrum object with native ID 853 at 0x7f8976137c10>,
#   <__main__.Spectrum object with native ID 1916 at 0x7f8976137cd0>,
#   <__main__.Spectrum object with native ID 1918 at 0x7f8976116700>,
#   <__main__.Spectrum object with native ID 1935 at 0x7f8975f34280>,
#   <__main__.Spectrum object with native ID 1937 at 0x7f8975f218e0>,
#   <__main__.Spectrum object with native ID 2156 at 0x7f8976129d30>,
#   <__main__.Spectrum object with native ID 2158 at 0x7f8976137940>],
#  'F11304': [],
#  'F11681': [],
#  'F11849': [],
#  'F12086': [],
#  'F12299': [<__main__.Spectrum object with native ID 2595 at 0x7f8975f48e20>,
#   <__main__.Spectrum object with native ID 2597 at 0x7f8976137d60>,
#   <__main__.Spectrum object with native ID 2615 at 0x7f8975f077f0>,
#   <__main__.Spectrum object with native ID 2617 at 0x7f8976116670>],
#  'F12928': [],
#  'F13180': [<__main__.Spectrum object with native ID 801 at 0x7f8975f21100>,
#   <__main__.Spectrum object with native ID 803 at 0x7f8975f21ee0>],
#  'F13184': [<__main__.Spectrum object with native ID 801 at 0x7f8975f340a0>,
#   <__main__.Spectrum object with native ID 803 at 0x7f8976116ac0>],
#  'F13352': [],
#  'F13368': [],
#  'F13523': [<__main__.Spectrum object with native ID 1856 at 0x7f8975f21a90>,
#   <__main__.Spectrum object with native ID 1858 at 0x7f8976129fa0>,
#   <__main__.Spectrum object with native ID 1876 at 0x7f8976116550>,
#   <__main__.Spectrum object with native ID 1878 at 0x7f8975f34820>],
#  'F13545': [<__main__.Spectrum object with native ID 1856 at 0x7f8975f21ac0>,
#   <__main__.Spectrum object with native ID 1858 at 0x7f8976137f10>,
#   <__main__.Spectrum object with native ID 1876 at 0x7f8976137a90>,
#   <__main__.Spectrum object with native ID 1878 at 0x7f8975f348e0>],
#  'F9678': [],
#  'F9693': [<__main__.Spectrum object with native ID 2346 at 0x7f8975f21880>,
#   <__main__.Spectrum object with native ID 2348 at 0x7f8975f213d0>,
#   <__main__.Spectrum object with native ID 2365 at 0x7f8975f21730>,
#   <__main__.Spectrum object with native ID 2367 at 0x7f8976137af0>],
#  'F9994': [],
#  'F10004': [<__main__.Spectrum object with native ID 1805 at 0x7f8975f34f70>,
#   <__main__.Spectrum object with native ID 1807 at 0x7f8976129700>,
#   <__main__.Spectrum object with native ID 1825 at 0x7f8975f48130>,
#   <__main__.Spectrum object with native ID 1827 at 0x7f8975f34160>,
#   <__main__.Spectrum object with native ID 1845 at 0x7f89761370a0>,
#   <__main__.Spectrum object with native ID 1847 at 0x7f8976129df0>,
#   <__main__.Spectrum object with native ID 1865 at 0x7f89761165b0>,
#   <__main__.Spectrum object with native ID 1867 at 0x7f8976116fa0>,
#   <__main__.Spectrum object with native ID 1886 at 0x7f8975f21340>,
#   <__main__.Spectrum object with native ID 1888 at 0x7f8975f483a0>,
#   <__main__.Spectrum object with native ID 1905 at 0x7f89761167c0>,
#   <__main__.Spectrum object with native ID 1907 at 0x7f8976116760>,
#   <__main__.Spectrum object with native ID 1925 at 0x7f8975f21370>,
#   <__main__.Spectrum object with native ID 1927 at 0x7f8976116100>,
#   <__main__.Spectrum object with native ID 1945 at 0x7f8975f21490>,
#   <__main__.Spectrum object with native ID 1947 at 0x7f8975f07580>],
#  'F10378': [<__main__.Spectrum object with native ID 2561 at 0x7f8976116730>,
#   <__main__.Spectrum object with native ID 2563 at 0x7f89761166a0>],
#  'F10628': [],
#  'F10649': [],
#  'F10790': [],
#  'F10809': [],
#  'F10998': [<__main__.Spectrum object with native ID 2286 at 0x7f8976116b20>,
#   <__main__.Spectrum object with native ID 2288 at 0x7f8976116250>],
#  'F11006': [],
#  'F11498': [],
#  'F11746': [],
#  'F12027': [],
#  'F12261': [],
#  'F12389': [],
#  'F12441': [],
#  'F12641': [<__main__.Spectrum object with native ID 1346 at 0x7f8976137790>,
#   <__main__.Spectrum object with native ID 1348 at 0x7f89761370d0>],
#  'F12902': [],
#  'F13048': [],
#  'F13079': [],
#  'F13395': [<__main__.Spectrum object with native ID 2751 at 0x7f8975d4e2b0>,
#   <__main__.Spectrum object with native ID 2753 at 0x7f8975f21c40>],
#  'F13488': [],
#  'F13638': [<__main__.Spectrum object with native ID 1496 at 0x7f8976116460>,
#   <__main__.Spectrum object with native ID 1498 at 0x7f8976116be0>,
#   <__main__.Spectrum object with native ID 1515 at 0x7f8975f34910>,
#   <__main__.Spectrum object with native ID 1517 at 0x7f8976137d90>,
#   <__main__.Spectrum object with native ID 1536 at 0x7f8976116c70>,
#   <__main__.Spectrum object with native ID 1538 at 0x7f8975f48fa0>],
#  'F13658': [<__main__.Spectrum object with native ID 1496 at 0x7f8975f073a0>,
#   <__main__.Spectrum object with native ID 1498 at 0x7f8975f34c10>,
#   <__main__.Spectrum object with native ID 1515 at 0x7f8975f21070>,
#   <__main__.Spectrum object with native ID 1517 at 0x7f8975f345e0>,
#   <__main__.Spectrum object with native ID 1536 at 0x7f8975f07b20>,
#   <__main__.Spectrum object with native ID 1538 at 0x7f8976137e50>],
#  'F12900': [],
#  'F12910': [],
#  'F13113': [],
#  'F13132': [<__main__.Spectrum object with native ID 2485 at 0x7f8976137430>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f89761297c0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f89761373a0>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f8976116cd0>],
#  'F13136': [<__main__.Spectrum object with native ID 2485 at 0x7f8976137f70>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f8976129eb0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f8976116910>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f8975f07a00>,
#   <__main__.Spectrum object with native ID 2975 at 0x7f8976137070>,
#   <__main__.Spectrum object with native ID 2977 at 0x7f8975f48910>],
#  'F13468': [<__main__.Spectrum object with native ID 1685 at 0x7f8976129d00>,
#   <__main__.Spectrum object with native ID 1687 at 0x7f8975f34af0>,
#   <__main__.Spectrum object with native ID 1705 at 0x7f8975f482b0>,
#   <__main__.Spectrum object with native ID 1707 at 0x7f8976137e20>],
#  'F13804': [],
#  'F14097': [],
#  'F14354': [<__main__.Spectrum object with native ID 1556 at 0x7f897815c490>,
#   <__main__.Spectrum object with native ID 1558 at 0x7f8975f34190>],
#  'F14607': [],
#  'F14831': [],
#  'F14998': [],
#  'F15014': [],
#  'F15086': [],
#  'F15244': [],
#  'F15257': [],
#  'F15440': [],
#  'F15464': [],
#  'F15666': [],
#  'F15734': [],
#  'F16070': [],
#  'F16127': [],
#  'F16286': [],
#  'F16333': [],
#  'F16346': [],
#  'F16535': [],
#  'F16561': [],
#  'F16926': [<__main__.Spectrum object with native ID 2685 at 0x7f8975f480a0>,
#   <__main__.Spectrum object with native ID 2687 at 0x7f8975f21f10>],
#  'F17105': [],
#  'F17235': [],
#  'F17396': [],
#  'F17530': [],
#  'F13805': [],
#  'F13961': [],
#  'F14243': [],
#  'F14588': [],
#  'F15491': [],
#  'F15637': [],
#  'F15865': [],
#  'F16120': []}

# %%
# items that don't have spectra associated
[k for k,v in res_dict.items() if len(v) == 0 ]
# Out:
# ['F1614',
#  'F3712',
#  'F1779',
#  'F3031',
#  'F4105',
#  'F4190',
#  'F5441',
#  'F5580',
#  'F5983',
#  'F6287',
#  'F6579',
#  'F6913',
#  'F7086',
#  'F7618',
#  'F5337',
#  'F7394',
#  'F9383',
#  'F9945',
#  'F11972',
#  'F12271',
#  'F12819',
#  'F9458',
#  'F9861',
#  'F11304',
#  'F11681',
#  'F11849',
#  'F12086',
#  'F12928',
#  'F13352',
#  'F13368',
#  'F9678',
#  'F9994',
#  'F10628',
#  'F10649',
#  'F10790',
#  'F10809',
#  'F11006',
#  'F11498',
#  'F11746',
#  'F12027',
#  'F12261',
#  'F12389',
#  'F12441',
#  'F12902',
#  'F13048',
#  'F13079',
#  'F13488',
#  'F12900',
#  'F12910',
#  'F13113',
#  'F13804',
#  'F14097',
#  'F14607',
#  'F14831',
#  'F14998',
#  'F15014',
#  'F15086',
#  'F15244',
#  'F15257',
#  'F15440',
#  'F15464',
#  'F15666',
#  'F15734',
#  'F16070',
#  'F16127',
#  'F16286',
#  'F16333',
#  'F16346',
#  'F16535',
#  'F16561',
#  'F17105',
#  'F17235',
#  'F17396',
#  'F17530',
#  'F13805',
#  'F13961',
#  'F14243',
#  'F14588',
#  'F15491',
#  'F15637',
#  'F15865',
#  'F16120']

# %%
res_dict_clean = {k:v for k,v in res_dict.items() if len(v) != 0}

# %%
res_dict_clean
# Out:
# {'F3138': [<__main__.Spectrum object with native ID 406 at 0x7f8975f210a0>,
#   <__main__.Spectrum object with native ID 408 at 0x7f8975f211f0>],
#  'F6328': [<__main__.Spectrum object with native ID 1411 at 0x7f8975f34bb0>,
#   <__main__.Spectrum object with native ID 1413 at 0x7f8976137b20>],
#  'F5343': [<__main__.Spectrum object with native ID 1475 at 0x7f8975f487f0>,
#   <__main__.Spectrum object with native ID 1477 at 0x7f8976116c40>],
#  'F10088': [<__main__.Spectrum object with native ID 1041 at 0x7f8976116a90>,
#   <__main__.Spectrum object with native ID 1043 at 0x7f8976116640>,
#   <__main__.Spectrum object with native ID 1250 at 0x7f8975f34b80>,
#   <__main__.Spectrum object with native ID 1252 at 0x7f8976129d90>,
#   <__main__.Spectrum object with native ID 1290 at 0x7f8975f34760>,
#   <__main__.Spectrum object with native ID 1292 at 0x7f8976129ee0>,
#   <__main__.Spectrum object with native ID 1371 at 0x7f8975f21520>,
#   <__main__.Spectrum object with native ID 1373 at 0x7f8975f34f10>],
#  'F12237': [<__main__.Spectrum object with native ID 2176 at 0x7f8975f48280>,
#   <__main__.Spectrum object with native ID 2178 at 0x7f8975f48e80>,
#   <__main__.Spectrum object with native ID 2195 at 0x7f8975f342b0>,
#   <__main__.Spectrum object with native ID 2197 at 0x7f8975f346d0>,
#   <__main__.Spectrum object with native ID 2215 at 0x7f8975f34a30>,
#   <__main__.Spectrum object with native ID 2217 at 0x7f8976137220>],
#  'F10486': [<__main__.Spectrum object with native ID 1141 at 0x7f8975f486d0>,
#   <__main__.Spectrum object with native ID 1143 at 0x7f8976116ee0>,
#   <__main__.Spectrum object with native ID 1160 at 0x7f8976116f10>,
#   <__main__.Spectrum object with native ID 1162 at 0x7f8975f21790>,
#   <__main__.Spectrum object with native ID 1181 at 0x7f8975f21f40>,
#   <__main__.Spectrum object with native ID 1183 at 0x7f89761375e0>,
#   <__main__.Spectrum object with native ID 1201 at 0x7f89761377f0>,
#   <__main__.Spectrum object with native ID 1203 at 0x7f8975f217f0>,
#   <__main__.Spectrum object with native ID 1221 at 0x7f8976137eb0>,
#   <__main__.Spectrum object with native ID 1223 at 0x7f8975f48160>,
#   <__main__.Spectrum object with native ID 1241 at 0x7f89761293a0>,
#   <__main__.Spectrum object with native ID 1243 at 0x7f8976116e20>,
#   <__main__.Spectrum object with native ID 1261 at 0x7f8975f34eb0>,
#   <__main__.Spectrum object with native ID 1263 at 0x7f8975f34b50>,
#   <__main__.Spectrum object with native ID 1296 at 0x7f8975f34790>,
#   <__main__.Spectrum object with native ID 1298 at 0x7f89761292b0>,
#   <__main__.Spectrum object with native ID 1386 at 0x7f8975f21e50>,
#   <__main__.Spectrum object with native ID 1388 at 0x7f8976129190>,
#   <__main__.Spectrum object with native ID 1405 at 0x7f8976129c10>,
#   <__main__.Spectrum object with native ID 1407 at 0x7f8975f07d90>,
#   <__main__.Spectrum object with native ID 1436 at 0x7f8976129280>,
#   <__main__.Spectrum object with native ID 1438 at 0x7f8975f07160>,
#   <__main__.Spectrum object with native ID 1455 at 0x7f8975f07e50>,
#   <__main__.Spectrum object with native ID 1457 at 0x7f8975f070d0>,
#   <__main__.Spectrum object with native ID 1540 at 0x7f8976129040>,
#   <__main__.Spectrum object with native ID 1542 at 0x7f8975f07eb0>,
#   <__main__.Spectrum object with native ID 1560 at 0x7f8976137d00>,
#   <__main__.Spectrum object with native ID 1562 at 0x7f8975f071f0>],
#  'F10386': [<__main__.Spectrum object with native ID 1666 at 0x7f89761165e0>,
#   <__main__.Spectrum object with native ID 1668 at 0x7f8976116310>,
#   <__main__.Spectrum object with native ID 1690 at 0x7f8975f21400>,
#   <__main__.Spectrum object with native ID 1692 at 0x7f8976116040>],
#  'F11014': [<__main__.Spectrum object with native ID 851 at 0x7f8975f48400>,
#   <__main__.Spectrum object with native ID 853 at 0x7f8976137c10>,
#   <__main__.Spectrum object with native ID 1916 at 0x7f8976137cd0>,
#   <__main__.Spectrum object with native ID 1918 at 0x7f8976116700>,
#   <__main__.Spectrum object with native ID 1935 at 0x7f8975f34280>,
#   <__main__.Spectrum object with native ID 1937 at 0x7f8975f218e0>,
#   <__main__.Spectrum object with native ID 2156 at 0x7f8976129d30>,
#   <__main__.Spectrum object with native ID 2158 at 0x7f8976137940>],
#  'F12299': [<__main__.Spectrum object with native ID 2595 at 0x7f8975f48e20>,
#   <__main__.Spectrum object with native ID 2597 at 0x7f8976137d60>,
#   <__main__.Spectrum object with native ID 2615 at 0x7f8975f077f0>,
#   <__main__.Spectrum object with native ID 2617 at 0x7f8976116670>],
#  'F13180': [<__main__.Spectrum object with native ID 801 at 0x7f8975f21100>,
#   <__main__.Spectrum object with native ID 803 at 0x7f8975f21ee0>],
#  'F13184': [<__main__.Spectrum object with native ID 801 at 0x7f8975f340a0>,
#   <__main__.Spectrum object with native ID 803 at 0x7f8976116ac0>],
#  'F13523': [<__main__.Spectrum object with native ID 1856 at 0x7f8975f21a90>,
#   <__main__.Spectrum object with native ID 1858 at 0x7f8976129fa0>,
#   <__main__.Spectrum object with native ID 1876 at 0x7f8976116550>,
#   <__main__.Spectrum object with native ID 1878 at 0x7f8975f34820>],
#  'F13545': [<__main__.Spectrum object with native ID 1856 at 0x7f8975f21ac0>,
#   <__main__.Spectrum object with native ID 1858 at 0x7f8976137f10>,
#   <__main__.Spectrum object with native ID 1876 at 0x7f8976137a90>,
#   <__main__.Spectrum object with native ID 1878 at 0x7f8975f348e0>],
#  'F9693': [<__main__.Spectrum object with native ID 2346 at 0x7f8975f21880>,
#   <__main__.Spectrum object with native ID 2348 at 0x7f8975f213d0>,
#   <__main__.Spectrum object with native ID 2365 at 0x7f8975f21730>,
#   <__main__.Spectrum object with native ID 2367 at 0x7f8976137af0>],
#  'F10004': [<__main__.Spectrum object with native ID 1805 at 0x7f8975f34f70>,
#   <__main__.Spectrum object with native ID 1807 at 0x7f8976129700>,
#   <__main__.Spectrum object with native ID 1825 at 0x7f8975f48130>,
#   <__main__.Spectrum object with native ID 1827 at 0x7f8975f34160>,
#   <__main__.Spectrum object with native ID 1845 at 0x7f89761370a0>,
#   <__main__.Spectrum object with native ID 1847 at 0x7f8976129df0>,
#   <__main__.Spectrum object with native ID 1865 at 0x7f89761165b0>,
#   <__main__.Spectrum object with native ID 1867 at 0x7f8976116fa0>,
#   <__main__.Spectrum object with native ID 1886 at 0x7f8975f21340>,
#   <__main__.Spectrum object with native ID 1888 at 0x7f8975f483a0>,
#   <__main__.Spectrum object with native ID 1905 at 0x7f89761167c0>,
#   <__main__.Spectrum object with native ID 1907 at 0x7f8976116760>,
#   <__main__.Spectrum object with native ID 1925 at 0x7f8975f21370>,
#   <__main__.Spectrum object with native ID 1927 at 0x7f8976116100>,
#   <__main__.Spectrum object with native ID 1945 at 0x7f8975f21490>,
#   <__main__.Spectrum object with native ID 1947 at 0x7f8975f07580>],
#  'F10378': [<__main__.Spectrum object with native ID 2561 at 0x7f8976116730>,
#   <__main__.Spectrum object with native ID 2563 at 0x7f89761166a0>],
#  'F10998': [<__main__.Spectrum object with native ID 2286 at 0x7f8976116b20>,
#   <__main__.Spectrum object with native ID 2288 at 0x7f8976116250>],
#  'F12641': [<__main__.Spectrum object with native ID 1346 at 0x7f8976137790>,
#   <__main__.Spectrum object with native ID 1348 at 0x7f89761370d0>],
#  'F13395': [<__main__.Spectrum object with native ID 2751 at 0x7f8975d4e2b0>,
#   <__main__.Spectrum object with native ID 2753 at 0x7f8975f21c40>],
#  'F13638': [<__main__.Spectrum object with native ID 1496 at 0x7f8976116460>,
#   <__main__.Spectrum object with native ID 1498 at 0x7f8976116be0>,
#   <__main__.Spectrum object with native ID 1515 at 0x7f8975f34910>,
#   <__main__.Spectrum object with native ID 1517 at 0x7f8976137d90>,
#   <__main__.Spectrum object with native ID 1536 at 0x7f8976116c70>,
#   <__main__.Spectrum object with native ID 1538 at 0x7f8975f48fa0>],
#  'F13658': [<__main__.Spectrum object with native ID 1496 at 0x7f8975f073a0>,
#   <__main__.Spectrum object with native ID 1498 at 0x7f8975f34c10>,
#   <__main__.Spectrum object with native ID 1515 at 0x7f8975f21070>,
#   <__main__.Spectrum object with native ID 1517 at 0x7f8975f345e0>,
#   <__main__.Spectrum object with native ID 1536 at 0x7f8975f07b20>,
#   <__main__.Spectrum object with native ID 1538 at 0x7f8976137e50>],
#  'F13132': [<__main__.Spectrum object with native ID 2485 at 0x7f8976137430>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f89761297c0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f89761373a0>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f8976116cd0>],
#  'F13136': [<__main__.Spectrum object with native ID 2485 at 0x7f8976137f70>,
#   <__main__.Spectrum object with native ID 2487 at 0x7f8976129eb0>,
#   <__main__.Spectrum object with native ID 2505 at 0x7f8976116910>,
#   <__main__.Spectrum object with native ID 2507 at 0x7f8975f07a00>,
#   <__main__.Spectrum object with native ID 2975 at 0x7f8976137070>,
#   <__main__.Spectrum object with native ID 2977 at 0x7f8975f48910>],
#  'F13468': [<__main__.Spectrum object with native ID 1685 at 0x7f8976129d00>,
#   <__main__.Spectrum object with native ID 1687 at 0x7f8975f34af0>,
#   <__main__.Spectrum object with native ID 1705 at 0x7f8975f482b0>,
#   <__main__.Spectrum object with native ID 1707 at 0x7f8976137e20>],
#  'F14354': [<__main__.Spectrum object with native ID 1556 at 0x7f897815c490>,
#   <__main__.Spectrum object with native ID 1558 at 0x7f8975f34190>],
#  'F16926': [<__main__.Spectrum object with native ID 2685 at 0x7f8975f480a0>,
#   <__main__.Spectrum object with native ID 2687 at 0x7f8975f21f10>]}

# %%
# this function only works for situation where you look at charge state = 1
def search_NL(spectra,
              NL_mz = 87.03124,
              ppm = 50):
    res_data = []

    for spec in spectra:
        selected_precursor_mz = spec.selected_precursors[0]['mz'] # this m/z will not be exactly the precursor m/z
        sel_mz = [mz for mz in spec.mz if abs(mz - selected_precursor_mz) < np.ceil(NL_mz)]

        for mz in sel_mz:
            calc_ppm = abs(((selected_precursor_mz - mz) - NL_mz)*1000000/NL_mz)
            if calc_ppm < ppm:
                print(calc_ppm)
                res_data.append(spec)
                break
    return res_data

# %%
res_dict = {}
for FTID, spectra in res_dict_clean.items():
    res_dict.update({FTID: search_NL(spectra)})
# Out:
# 26.063064038620475
# 26.764365734999846
# 22.55655555672363
# 23.257857253102998

# %%
res_dict
# Out:
# {'F3138': [],
#  'F6328': [],
#  'F5343': [],
#  'F10088': [],
#  'F12237': [],
#  'F10486': [],
#  'F10386': [],
#  'F11014': [],
#  'F12299': [],
#  'F13180': [],
#  'F13184': [],
#  'F13523': [],
#  'F13545': [],
#  'F9693': [],
#  'F10004': [],
#  'F10378': [],
#  'F10998': [],
#  'F12641': [],
#  'F13395': [],
#  'F13638': [],
#  'F13658': [],
#  'F13132': [],
#  'F13136': [],
#  'F13468': [<__main__.Spectrum object with native ID 1685 at 0x7f8976129d00>,
#   <__main__.Spectrum object with native ID 1687 at 0x7f8975f34af0>,
#   <__main__.Spectrum object with native ID 1705 at 0x7f8975f482b0>,
#   <__main__.Spectrum object with native ID 1707 at 0x7f8976137e20>],
#  'F14354': [],
#  'F16926': []}

# %% [markdown]
# # plot accordingly

# %%
res_dict_clean.keys()
# Out:
# dict_keys(['F3138', 'F6328', 'F5343', 'F10088', 'F12237', 'F10486', 'F10386', 'F11014', 'F12299', 'F13180', 'F13184', 'F13523', 'F13545', 'F9693', 'F10004', 'F10378', 'F10998', 'F12641', 'F13395', 'F13638', 'F13658', 'F13132', 'F13136', 'F13468', 'F14354', 'F16926'])

# %%
df_sel.index = df_sel['id_number']

# %%
df_sel.columns[0:6]
# Out:
# Index(['query_target', 'id_number', 'mz', 'rtime', 'rtime_left_base',
#        'rtime_right_base'],
#       dtype='object')

# %%
for FTID in res_dict_clean.keys():
    plot_spectra(spectra = res_dict_clean[FTID], 
                 save_figure=True,
                 output_path=f"./data/output/{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}/",
                 label = f"{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}"
                 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species.Shorthand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
#       1 for FTID in res_dict_clean.keys():
#       2     plot_spectra(spectra = res_dict_clean[FTID],
#       3                  save_figure=True,
# ----> 4                  output_path=f"./data/output/{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}/",
#       5                  label = f"{FTID}_{df_sel.loc[FTID,'Species.Shorthand']}"
#       6                  )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3616, in DataFrame._get_value(self, index, col, takeable)
#    3613     series = self._ixs(col, axis=1)
#    3614     return series._values[index]
# -> 3616 series = self._get_item_cache(col)
#    3617 engine = self.index._engine
#    3619 if not isinstance(self.index, MultiIndex):
#    3620     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3621     #  results if our categories are integers that dont match our codes
#    3622     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3939, in DataFrame._get_item_cache(self, item)
#    3934 res = cache.get(item)
#    3935 if res is None:
#    3936     # All places that call _get_item_cache have unique columns,
#    3937     #  pending resolution of GH#33047
# -> 3939     loc = self.columns.get_loc(item)
#    3940     res = self._ixs(loc, axis=1)
#    3942     cache[item] = res
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Species.Shorthand'
